# %% [markdown]
# <a href="https://colab.research.google.com/github/peppopi/Piratas/blob/main/_Safestensor_To_Ckpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@markdown ### 5️⃣ Dependencias
# !pip install safetensors

# %%
#@markdown ### 5️⃣ Descarga desde dos url
from tqdm import tqdm

def descargar_archivo(url, nombre_archivo):
    # Descargar el archivo con barra de progreso
    response = requests.get(url, stream=True)
    total_size = int(response.headers.get("content-length", 0))

    # Guardar el archivo en tu entorno de ejecución con barra de progreso
    with open(nombre_archivo, "wb") as archivo:
        progress_bar = tqdm(total=total_size, unit="B", unit_scale=True)
        for data in response.iter_content(chunk_size=4096):
            archivo.write(data)
            progress_bar.update(len(data))
        progress_bar.close()

# URL del primer archivo que deseas descargar
url1 = "https://civitai.com/api/download/models/15236"  #@param {type:"string"}
# Nombre del primer archivo en tu entorno de ejecución
nombre_archivo1 = "Nomana.safetensors"

# Descargar el primer archivo
descargar_archivo(url1, nombre_archivo1)

# URL del segundo archivo que deseas descargar
url2 = "https://civitai.com/api/download/models/17233"   #@param {type:"string"}
# Nombre del segundo archivo en tu entorno de ejecución
nombre_archivo2 = "archivo2.safetensors"

# Descargar el segundo archivo
descargar_archivo(url2, nombre_archivo2)

# %%
#@markdown ### 5️⃣ Tranforma el modelo de .safestensor a .ckpt
import os
import torch
from safetensors.torch import load_file

file_path = '/content/Nomana.safetensors' #@param {type:"string"}

if not os.path.isfile(file_path):
    print("El archivo no existe.")
else:
    if file_path.lower().endswith('.safetensors'):
        print(f'Loading {file_path}...')
        fn = f"{file_path.replace('.safetensors', '')}.ckpt"

        if os.path.isfile(fn):
            print(f'Skipping, as {fn} already exists.')
        else:
            try:
                tensors = load_file(file_path)
                print(f'Tensors loaded successfully.')

                # Aquí puedes realizar operaciones con los tensores cargados

                # Guardar los tensores en un archivo .ckpt
                state_dict = {key: tensor for key, tensor in tensors.items()}
                print(f'Saving {fn}...')
                torch.save(state_dict, fn)
            except Exception as ex:
                print(f'ERROR converting {file_path}: {ex}')
    else:
        print("El archivo no es un archivo .safetensors.")

print('Terminaste')
# Out:
# Loading /content/Nomana.safetensors...
# Tensors loaded successfully.
# Saving /content/Nomana.ckpt...
# Terminaste

# %%
#@markdown ### 5️⃣ Verificamos los tensores para garantizar la convercion
import torch

file_path = '/content/Nomana.ckpt' #@param {type:"string"}

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

try:
    checkpoint = torch.load(file_path, map_location=device)
    print("Contenidos del archivo .ckpt:")
    print("-" * 40)
    print("Parámetros disponibles:")
    for key in checkpoint.keys():
        print(key)
    print("-" * 40)
    print("Información de cada parámetro:")
    for key, value in checkpoint.items():
        print(f"Parámetro: {key}")
        print(f"Tipo del valor: {type(value)}")
        print(f"Forma del tensor: {value.shape}")
        print(f"Dispositivo del tensor: {value.device}")
        print("-" * 20)
except Exception as ex:
    print(f'ERROR al cargar el archivo .ckpt: {ex}')
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.6.layer_norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.6.layer_norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.6.layer_norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.6.layer_norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.6.mlp.fc1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([3072])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.6.mlp.fc1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([3072, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.6.mlp.fc2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.6.mlp.fc2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 3072])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.6.self_attn.k_proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.6.self_attn.k_proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.6.self_attn.out_proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.6.self_attn.out_proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.6.self_attn.q_proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.6.self_attn.q_proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.6.self_attn.v_proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.6.self_attn.v_proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.7.layer_norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.7.layer_norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.7.layer_norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.7.layer_norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.7.mlp.fc1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([3072])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.7.mlp.fc1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([3072, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.7.mlp.fc2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.7.mlp.fc2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 3072])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.7.self_attn.k_proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.7.self_attn.k_proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.7.self_attn.out_proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.7.self_attn.out_proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.7.self_attn.q_proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.7.self_attn.q_proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.7.self_attn.v_proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.7.self_attn.v_proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.8.layer_norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.8.layer_norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.8.layer_norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.8.layer_norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.8.mlp.fc1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([3072])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.8.mlp.fc1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([3072, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.8.mlp.fc2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.8.mlp.fc2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 3072])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.8.self_attn.k_proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.8.self_attn.k_proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.8.self_attn.out_proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.8.self_attn.out_proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.8.self_attn.q_proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.8.self_attn.q_proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.8.self_attn.v_proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.8.self_attn.v_proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.9.layer_norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.9.layer_norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.9.layer_norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.9.layer_norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.9.mlp.fc1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([3072])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.9.mlp.fc1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([3072, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.9.mlp.fc2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.9.mlp.fc2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 3072])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.9.self_attn.k_proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.9.self_attn.k_proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.9.self_attn.out_proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.9.self_attn.out_proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.9.self_attn.q_proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.9.self_attn.q_proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.9.self_attn.v_proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.encoder.layers.9.self_attn.v_proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.final_layer_norm.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: cond_stage_model.transformer.text_model.final_layer_norm.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.conv_in.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.conv_in.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 4, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.conv_out.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.conv_out.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([3, 128, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.attn_1.k.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.attn_1.k.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 1, 1])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.attn_1.norm.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.attn_1.norm.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.attn_1.proj_out.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.attn_1.proj_out.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 1, 1])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.attn_1.q.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.attn_1.q.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 1, 1])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.attn_1.v.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.attn_1.v.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 1, 1])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.block_1.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.block_1.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.block_1.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.block_1.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.block_1.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.block_1.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.block_1.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.block_1.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.block_2.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.block_2.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.block_2.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.block_2.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.block_2.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.block_2.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.block_2.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.mid.block_2.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.norm_out.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.norm_out.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.0.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.0.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128, 256, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.0.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.0.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128, 128, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.0.nin_shortcut.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.0.nin_shortcut.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128, 256, 1, 1])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.0.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.0.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.0.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.0.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.1.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.1.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128, 128, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.1.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.1.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128, 128, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.1.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.1.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.1.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.1.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.2.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.2.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128, 128, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.2.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.2.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128, 128, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.2.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.2.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.2.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.0.block.2.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.0.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.0.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.0.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.0.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256, 256, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.0.nin_shortcut.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.0.nin_shortcut.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256, 512, 1, 1])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.0.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.0.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.0.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.0.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.1.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.1.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256, 256, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.1.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.1.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256, 256, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.1.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.1.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.1.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.1.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.2.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.2.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256, 256, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.2.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.2.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256, 256, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.2.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.2.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.2.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.block.2.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.upsample.conv.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.1.upsample.conv.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256, 256, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.0.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.0.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.0.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.0.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.0.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.0.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.0.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.0.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.1.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.1.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.1.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.1.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.1.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.1.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.1.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.1.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.2.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.2.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.2.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.2.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.2.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.2.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.2.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.block.2.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.upsample.conv.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.2.upsample.conv.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.0.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.0.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.0.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.0.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.0.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.0.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.0.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.0.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.1.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.1.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.1.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.1.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.1.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.1.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.1.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.1.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.2.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.2.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.2.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.2.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.2.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.2.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.2.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.block.2.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.upsample.conv.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.decoder.up.3.upsample.conv.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([512, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.conv_in.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.conv_in.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128, 3, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.conv_out.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([8])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.conv_out.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([8, 512, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.block.0.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.block.0.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128, 128, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.block.0.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.block.0.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128, 128, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.block.0.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.block.0.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.block.0.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.block.0.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.block.1.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.block.1.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128, 128, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.block.1.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.block.1.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128, 128, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.block.1.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.block.1.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.block.1.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.block.1.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.downsample.conv.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.0.downsample.conv.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128, 128, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.0.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.0.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256, 128, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.0.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.0.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256, 256, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.0.nin_shortcut.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.0.nin_shortcut.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256, 128, 1, 1])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.0.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.0.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([128])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.0.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.0.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.1.conv1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.1.conv1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256, 256, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.1.conv2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.1.conv2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256, 256, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.1.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.1.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.1.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.block.1.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: first_stage_model.encoder.down.1.downsample.conv.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([256])
# Dispositivo del tensor: cpu
# --------------------
# ...
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.0.in_layers.2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.0.in_layers.2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640, 960, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.0.out_layers.0.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.0.out_layers.0.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.0.out_layers.3.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.0.out_layers.3.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640, 640, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.0.skip_connection.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.0.skip_connection.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640, 960, 1, 1])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.norm.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.norm.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.proj_in.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.proj_in.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640, 640, 1, 1])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.proj_out.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.proj_out.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640, 640, 1, 1])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn1.to_k.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640, 640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn1.to_out.0.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn1.to_out.0.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640, 640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn1.to_q.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640, 640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn1.to_v.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640, 640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn2.to_k.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn2.to_out.0.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn2.to_out.0.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640, 640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn2.to_q.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640, 640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn2.to_v.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.ff.net.0.proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([5120])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.ff.net.0.proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([5120, 640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.ff.net.2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.ff.net.2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640, 2560])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.norm3.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.1.transformer_blocks.0.norm3.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.2.conv.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.8.2.conv.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([640, 640, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.0.emb_layers.1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.0.emb_layers.1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320, 1280])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.0.in_layers.0.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([960])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.0.in_layers.0.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([960])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.0.in_layers.2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.0.in_layers.2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320, 960, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.0.out_layers.0.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.0.out_layers.0.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.0.out_layers.3.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.0.out_layers.3.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320, 320, 3, 3])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.0.skip_connection.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.0.skip_connection.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320, 960, 1, 1])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.norm.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.norm.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.proj_in.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.proj_in.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320, 320, 1, 1])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.proj_out.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.proj_out.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320, 320, 1, 1])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn1.to_k.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320, 320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn1.to_out.0.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn1.to_out.0.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320, 320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn1.to_q.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320, 320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn1.to_v.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320, 320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn2.to_k.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn2.to_out.0.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn2.to_out.0.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320, 320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn2.to_q.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320, 320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn2.to_v.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320, 768])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.ff.net.0.proj.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([2560])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.ff.net.0.proj.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([2560, 320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.ff.net.2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.ff.net.2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320, 1280])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.norm1.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.norm1.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.norm2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.norm2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.norm3.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.output_blocks.9.1.transformer_blocks.0.norm3.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.time_embed.0.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([1280])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.time_embed.0.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([1280, 320])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.time_embed.2.bias
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([1280])
# Dispositivo del tensor: cpu
# --------------------
# Parámetro: model.diffusion_model.time_embed.2.weight
# Tipo del valor: <class 'torch.Tensor'>
# Forma del tensor: torch.Size([1280, 1280])
# Dispositivo del tensor: cpu
# --------------------
